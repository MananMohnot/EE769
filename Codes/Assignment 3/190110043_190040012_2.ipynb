# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import sklearn

# %%
url_cluster="https://www.ee.iitb.ac.in/~asethi/Dump/DataClustering.csv" #referencing url of data
df_cluster = pd.read_csv(url_cluster) #importing train data
display(df_cluster) # display train data
# Out:
#            x1        x2        x3        x4
# 0    0.832354  1.389428  0.962226  0.993671
# 1    1.256087  1.500487  0.904118  0.738035
# 2    0.976953  1.058524  1.217530  1.357238
# 3    1.014365  1.122684  1.195847  0.984144
# 4    1.041386  1.219014  0.864819  1.720825
# ..        ...       ...       ...       ...
# 346  0.203877  0.195724  2.766999  1.826532
# 347  0.229380  0.131514  0.704255  2.762919
# 348  0.095878  0.107426  0.946789  3.434620
# 349  0.111690  0.130970  1.098922  2.295701
# 350  0.113965  0.283822  1.318260  1.494283
#
# [351 rows x 4 columns]

# %%
pd.plotting.scatter_matrix(df_cluster)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0a8324a7d0>,
# ...
#       dtype=object)

# %%
df_transformed = np.log(df_cluster) #log transformation

# %%
pd.plotting.scatter_matrix(df_transformed)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0a82830f50>,
# ...
#       dtype=object)

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=5, random_state=0).fit(df_transformed)
predicted_clusters = kmeans.fit_predict(df_transformed)
pd.plotting.scatter_matrix(df_transformed,c=predicted_clusters,cmap='rainbow')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0a82e28e50>,
# ...
#       dtype=object)

# %%
from sklearn.manifold import TSNE

# %%
# Create a two dimensional t-SNE projection of the embeddings
tsne = TSNE(n_components=2, verbose=1, perplexity=80, n_iter=5000, learning_rate='auto')
tsne_proj = tsne.fit_transform(df_transformed)
tsne_df = pd.DataFrame(tsne_proj, columns=['tsne1', 'tsne2'])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 241 nearest neighbors...
# [t-SNE] Indexed 351 samples in 0.002s...
# [t-SNE] Computed neighbors for 351 samples in 0.039s...
# [t-SNE] Computed conditional probabilities for sample 351 / 351
# [t-SNE] Mean sigma: 0.707806
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 43.579109
# [t-SNE] KL divergence after 2050 iterations: 0.249094

# %%
pd.plotting.scatter_matrix(tsne_df,c=predicted_clusters,cmap='rainbow')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0a7abc8ed0>,
# ...
#       dtype=object)
