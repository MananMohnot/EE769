# %%
import zipfile
import os 

# !wget --no-check-certificate \ "https://github.com/MananMohnot/DATA_DUMP/archive/refs/heads/main.zip" \ -O "/tmp/main.zip"
zip_ref = zipfile.ZipFile('/tmp/main.zip', 'r') #Opens the zip file in read mode
zip_ref.extractall('/tmp') #Extracts the files into the /tmp folder
zip_ref.close()
# Out:
#  https://github.com/MananMohnot/DATA_DUMP/archive/refs/heads/main.zip: Scheme missing.
# --2022-05-07 07:59:29--  http://%20-o/
# Resolving  -o ( -o)... failed: Name or service not known.
# wget: unable to resolve host address ‘ -o’
# /tmp/main.zip: Scheme missing.
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-10-0c6a5e6370a0> in <module>()
#       3
#       4 get_ipython().system('wget --no-check-certificate \\ "https://github.com/MananMohnot/DATA_DUMP/archive/refs/heads/main.zip" \\ -O "/tmp/main.zip"')
# ----> 5 zip_ref = zipfile.ZipFile('/tmp/main.zip', 'r') #Opens the zip file in read mode
#       6 zip_ref.extractall('/tmp') #Extracts the files into the /tmp folder
#       7 zip_ref.close()
#
# /usr/lib/python3.7/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1256         try:
#    1257             if mode == 'r':
# ...
